# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carga desde un archivo .csv sin indice
df = pd.read_csv('Amsterdam.csv')
df = df.drop(columns = ["Unnamed: 0.1", "Unnamed: 0"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  9659 non-null   object
#  1   name                                          9659 non-null   object
#  2   host_name                                     9659 non-null   object
#  3   host_since                                    9659 non-null   object
#  4   host_response_time                            9659 non-null   object
#  5   host_response_rate                            9659 non-null   object
#  6   host_acceptance_rate                          9659 non-null   object
#  7   host_is_superhost                             9659 non-null   object
#  8   host_identity_verified                        9659 non-null   object
# ...

# %%
# FILTRO POR OBJETO
filtro = df[(df["room_type"] == "Entire home/apt")]
filtro
# Out:
#      last_scraped                                            name  host_name  \
# 0      2024-09-05             Warm, cozy sunlighted downtown appt     Jeroen
# 1      2024-09-05                   Cozy apartment in city center       Theo
# 2      2024-09-05              Loft style home nearby city centre    Marijke
# 3      2024-09-06  Geweldige duurzame eco woonark op unieke plek!    Marloes
# 5      2024-09-05             Cozy apartment at a great location!     Zohair
# ...           ...                                             ...        ...
# 9654   2024-09-05                      Luxe appartement Amsterdam  Ramandeep
# 9655   2024-09-05                                          Vrolik      Ellen
# 9656   2024-09-05                 Kids friendly home next to park    Olivier
# 9657   2024-09-05                        Cosy home in city center       Nina
# 9658   2024-09-05                Most central amsterdam chic home      Laura
#
# ...

# %%
# FILTRO POR OBJETO
filtro = df[(df["room_type"] == "Entire home/apt")]

#CONVERTIR ARCHIVO FILTRADO A CSV
filtro.to_csv("Amsterdam_EntireHomeApt.csv")

# %%
# FILTRO POR OBJETO
filtro1 = df[(df["room_type"] == "Private room")]

#CONVERTIR ARCHIVO FILTRADO A CSV
filtro1.to_csv("Amsterdam_PrivateRoom.csv")

# %%
# FILTRO POR OBJETO
filtro2 = df[(df["room_type"] == "Shared room")]

#CONVERTIR ARCHIVO FILTRADO A CSV
filtro2.to_csv("Amsterdam_SharedRoom.csv")

# %%
# FILTRO POR OBJETO
filtro3 = df[(df["room_type"] == "Hotel room")]

#CONVERTIR ARCHIVO FILTRADO A CSV
filtro3.to_csv("Amsterdam_HotelRoom.csv")
